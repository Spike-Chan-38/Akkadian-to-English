# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Read in data here
train = pd.read_csv("../../Akkadian to English (Data)/data/train.csv")
test =  pd.read_csv("../../Akkadian to English (Data)/data/test.csv")
published_texts = pd.read_csv("../../Akkadian to English (Data)/data/published_texts.csv")

# %%
# Checks after reading in the data

published_texts.head()
# Out:
#                                 oare_id  \
# 0  bd4b7138-70d5-490d-8234-299b0a75d3a3
# 1  b05376c2-fc3d-49f8-9792-a25c0df9c383
# 2  80547963-f2a2-4d5d-9544-fc7ada60d3b2
# 3  8c0d4238-f795-4061-8b3c-8469a66d86d6
# 4  2c0d870b-cd5e-fc36-8d81-114ecc7a9ac4
#
#                                    online transcript  cdli_id  \
# 0  https://oare.byu.edu/epigraphies/bd4b7138-70d5...  P361099
# 1  https://oare.byu.edu/epigraphies/b05376c2-fc3d...  P359543
# 2  https://oare.byu.edu/epigraphies/80547963-f2a2...  P361681
# 3  https://oare.byu.edu/epigraphies/8c0d4238-f795...  P361098
# 4  https://oare.byu.edu/epigraphies/2c0d870b-cd5e...  P290300
#
#                    aliases                                   label  \
# 0                 MP 1 bis              Cuneiform Tablet RA 60 125
# 1                ICK 1 146              Cuneiform Tablet ICK 1 146
# 2  TrMA 1 | Or 36 396 n. 2           Cuneiform Tablet Or 36 396A.2
# 3                     MP 1              Cuneiform Tablet RA 60 123
# ...
